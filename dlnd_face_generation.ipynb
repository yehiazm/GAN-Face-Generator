# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    # TODO: Implement function and return a dataloader
    
    transform = transforms.Compose([transforms.Resize(image_size), transforms.ToTensor()])
    data = datasets.ImageFolder(data_dir,transform=transform)
    data_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = (x*(max-min)) + min 
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.7255)
# Max:  tensor(0.8588)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_Norm= True):
    layers = []
    conv_layer = nn.Conv2d(in_channels,out_channels,
                           kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)
    
    if batch_Norm:
        layers.append(nn.BatchNorm2d(out_channels))
    
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        self.conv_dim = conv_dim
        # complete init function
        self.conv1 = conv(3, conv_dim,4, batch_Norm=False)
        self.conv2 = conv(conv_dim, 2*conv_dim,4)
        self.conv3 = conv(2*conv_dim, 4*conv_dim,4)
        self.conv4 = conv(4*conv_dim, 8*conv_dim,4)
        
        self.fc = nn.Linear(2*2*8*conv_dim,1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        x = F.leaky_relu(self.conv4(x), 0.2)
        
        x = x.view(-1, 2*2*8*self.conv_dim)
        
        x = self.fc(x)
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_Norm=True):
    
    layers=[]
    deconv_layer= nn.ConvTranspose2d(in_channels,out_channels,kernel_size,
                                    stride, padding, bias= False)
    layers.append(deconv_layer)
    if batch_Norm:
        layers.append(nn.BatchNorm2d(out_channels))
    
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        
        self.conv_dim = conv_dim
        
        self.fc = nn.Linear(z_size, 2*2*8*conv_dim)
        self.deconv1 = deconv(8*conv_dim, 4*conv_dim,4)
        self.deconv2 = deconv(4*conv_dim, 2*conv_dim,4)
        self.deconv3 = deconv(2*conv_dim,   conv_dim,4)
        self.deconv4 = deconv(conv_dim, 3, 4, batch_Norm=False)
        
        # complete init function
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        out = self.fc(x)
        out = out.view(-1,8*self.conv_dim,2,2)
        
        out = F.relu(self.deconv1(out))
        out = F.relu(self.deconv2(out))
        out = F.relu(self.deconv3(out))
        
        out = F.tanh(self.deconv4(out))
        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    if hasattr(m, 'weight') and (classname.find('Conv')!= 0 or classname.find('Linear')!=0):
        nn.init.normal_(m.weight.data,0.0,0.02)
        if hasattr(m,'bias') and m.bias is not None: 
            nn.init.constant_(m.bias.data, 0.0)
    # TODO: Apply initial weights to convolutional and linear layers

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 128 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=128, out_features=2048, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    labels= torch.ones(batch_size)
    criterion = nn.BCEWithLogitsLoss()
    
    if train_on_gpu:
        labels = labels.cuda()

    loss = criterion(D_out.squeeze(),labels)
    
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels= torch.zeros(batch_size)
    criterion = nn.BCEWithLogitsLoss()
    if train_on_gpu:
        labels = labels.cuda()

    loss = criterion(D_out.squeeze(),labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim
lr = 0.0002 
beta1 =0.5 
beta2 =0.9 
# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(),lr,[beta1, beta2])
g_optimizer = optim.Adam(G.parameters(),lr,[beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            if train_on_gpu:
                real_images = real_images.cuda()
            #Zero gradient
            d_optimizer.zero_grad()
            
            # 1. Train the discriminator on real and fake images
            #Calculate real loss
            d_real_out = D(real_images)
            d_real_loss= real_loss(d_real_out)
            
            #Generate Fake images
            z = np.random.uniform(-1,1,size=(batch_size,z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda() 
            fake_images_d= G(z)
            d_fake_out= D(fake_images_d)
            d_fake_loss= fake_loss(d_fake_out)
            
            d_loss = d_real_loss + d_fake_loss
            
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            z = np.random.uniform(-1,1,size=(batch_size,z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda() 
            fake_images_g= G(z)
            d_g_out= D(fake_images_g)
            
            #Calculate flipped losses
            g_loss = real_loss(d_g_out)
            
            g_loss.backward()
            g_optimizer.step()
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 12


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   12] | d_loss: 0.5154 | g_loss: 2.1563
# Epoch [    1/   12] | d_loss: 0.7397 | g_loss: 1.1932
# Epoch [    1/   12] | d_loss: 0.6376 | g_loss: 2.8340
# Epoch [    1/   12] | d_loss: 0.9357 | g_loss: 2.6730
# Epoch [    1/   12] | d_loss: 0.6601 | g_loss: 1.4360
# Epoch [    1/   12] | d_loss: 1.2218 | g_loss: 2.0763
# Epoch [    1/   12] | d_loss: 0.4789 | g_loss: 1.8747
# Epoch [    1/   12] | d_loss: 0.7471 | g_loss: 1.7447
# Epoch [    1/   12] | d_loss: 1.2403 | g_loss: 0.4513
# Epoch [    1/   12] | d_loss: 1.0577 | g_loss: 0.6030
# Epoch [    1/   12] | d_loss: 0.7426 | g_loss: 1.2826
# Epoch [    1/   12] | d_loss: 0.8992 | g_loss: 1.7287
# Epoch [    1/   12] | d_loss: 1.3878 | g_loss: 2.1429
# Epoch [    1/   12] | d_loss: 0.8793 | g_loss: 2.0482
# Epoch [    1/   12] | d_loss: 0.6772 | g_loss: 1.7321
# Epoch [    2/   12] | d_loss: 0.4916 | g_loss: 1.5865
# Epoch [    2/   12] | d_loss: 0.7458 | g_loss: 2.5801
# Epoch [    2/   12] | d_loss: 0.6977 | g_loss: 2.4745
# Epoch [    2/   12] | d_loss: 0.9238 | g_loss: 0.6357
# Epoch [    2/   12] | d_loss: 1.8681 | g_loss: 2.4079
# Epoch [    2/   12] | d_loss: 0.9120 | g_loss: 2.5894
# Epoch [    2/   12] | d_loss: 1.1533 | g_loss: 2.9050
# Epoch [    2/   12] | d_loss: 0.8725 | g_loss: 2.3008
# Epoch [    2/   12] | d_loss: 0.7361 | g_loss: 1.6032
# Epoch [    2/   12] | d_loss: 1.1506 | g_loss: 3.0579
# Epoch [    2/   12] | d_loss: 0.7464 | g_loss: 1.5689
# Epoch [    2/   12] | d_loss: 0.9108 | g_loss: 1.7650
# Epoch [    2/   12] | d_loss: 0.9048 | g_loss: 2.4701
# Epoch [    2/   12] | d_loss: 0.5536 | g_loss: 2.0660
# Epoch [    2/   12] | d_loss: 0.7777 | g_loss: 2.3416
# Epoch [    3/   12] | d_loss: 0.8732 | g_loss: 1.7399
# Epoch [    3/   12] | d_loss: 0.5347 | g_loss: 2.3868
# Epoch [    3/   12] | d_loss: 0.8576 | g_loss: 1.2640
# Epoch [    3/   12] | d_loss: 0.9285 | g_loss: 1.9078
# Epoch [    3/   12] | d_loss: 0.6191 | g_loss: 0.7851
# Epoch [    3/   12] | d_loss: 0.6155 | g_loss: 2.3684
# Epoch [    3/   12] | d_loss: 0.5280 | g_loss: 1.0313
# Epoch [    3/   12] | d_loss: 0.9865 | g_loss: 0.6374
# Epoch [    3/   12] | d_loss: 0.6072 | g_loss: 2.9597
# Epoch [    3/   12] | d_loss: 0.7144 | g_loss: 2.5052
# Epoch [    3/   12] | d_loss: 0.4266 | g_loss: 0.7373
# Epoch [    3/   12] | d_loss: 0.5778 | g_loss: 1.8173
# Epoch [    3/   12] | d_loss: 0.7620 | g_loss: 1.4454
# Epoch [    3/   12] | d_loss: 0.6633 | g_loss: 3.1696
# Epoch [    4/   12] | d_loss: 0.6499 | g_loss: 1.2125
# Epoch [    4/   12] | d_loss: 0.8663 | g_loss: 1.8428
# Epoch [    4/   12] | d_loss: 0.4674 | g_loss: 1.6744
# Epoch [    4/   12] | d_loss: 0.5927 | g_loss: 2.3391
# Epoch [    4/   12] | d_loss: 0.7600 | g_loss: 2.0755
# Epoch [    4/   12] | d_loss: 0.5981 | g_loss: 1.9909
# Epoch [    4/   12] | d_loss: 0.7990 | g_loss: 1.7523
# Epoch [    4/   12] | d_loss: 0.8265 | g_loss: 4.0943
# Epoch [    4/   12] | d_loss: 0.9770 | g_loss: 0.8381
# Epoch [    4/   12] | d_loss: 1.5428 | g_loss: 2.6065
# Epoch [    5/   12] | d_loss: 0.9012 | g_loss: 2.6730
# Epoch [    5/   12] | d_loss: 0.9868 | g_loss: 2.2380
# Epoch [    5/   12] | d_loss: 0.5132 | g_loss: 2.4321
# Epoch [    5/   12] | d_loss: 0.8865 | g_loss: 3.7958
# Epoch [    5/   12] | d_loss: 0.7435 | g_loss: 1.3097
# Epoch [    5/   12] | d_loss: 0.5726 | g_loss: 0.8720
# Epoch [    5/   12] | d_loss: 0.5005 | g_loss: 2.6178
# Epoch [    5/   12] | d_loss: 0.4244 | g_loss: 2.3678
# Epoch [    5/   12] | d_loss: 0.9153 | g_loss: 0.9360
# Epoch [    5/   12] | d_loss: 0.6426 | g_loss: 0.8419
# Epoch [    5/   12] | d_loss: 0.6605 | g_loss: 2.4320
# Epoch [    5/   12] | d_loss: 0.4701 | g_loss: 3.0748
# Epoch [    5/   12] | d_loss: 0.5874 | g_loss: 1.7329
# Epoch [    5/   12] | d_loss: 0.6319 | g_loss: 2.0412
# Epoch [    5/   12] | d_loss: 0.6601 | g_loss: 2.1961
# Epoch [    6/   12] | d_loss: 0.6475 | g_loss: 2.5396
# Epoch [    6/   12] | d_loss: 0.5718 | g_loss: 2.0352
# Epoch [    6/   12] | d_loss: 0.3396 | g_loss: 1.4637
# Epoch [    6/   12] | d_loss: 0.9333 | g_loss: 0.9125
# Epoch [    6/   12] | d_loss: 0.4213 | g_loss: 2.6393
# Epoch [    6/   12] | d_loss: 0.8474 | g_loss: 1.8979
# Epoch [    6/   12] | d_loss: 1.1191 | g_loss: 3.6991
# Epoch [    6/   12] | d_loss: 0.4612 | g_loss: 2.8975
# Epoch [    6/   12] | d_loss: 0.4651 | g_loss: 2.5860
# Epoch [    6/   12] | d_loss: 1.2314 | g_loss: 2.2395
# Epoch [    6/   12] | d_loss: 0.8098 | g_loss: 1.6778
# Epoch [    6/   12] | d_loss: 0.3381 | g_loss: 2.1451
# Epoch [    6/   12] | d_loss: 0.5826 | g_loss: 2.2562
# Epoch [    6/   12] | d_loss: 0.7241 | g_loss: 1.0775
# Epoch [    6/   12] | d_loss: 0.5234 | g_loss: 2.8337
# Epoch [    7/   12] | d_loss: 0.5718 | g_loss: 2.9892
# Epoch [    7/   12] | d_loss: 0.4721 | g_loss: 2.0993
# Epoch [    7/   12] | d_loss: 0.2555 | g_loss: 1.9910
# Epoch [    7/   12] | d_loss: 1.2565 | g_loss: 1.2807
# Epoch [    7/   12] | d_loss: 0.3544 | g_loss: 2.1266
# Epoch [    7/   12] | d_loss: 0.5051 | g_loss: 2.1587
# Epoch [    7/   12] | d_loss: 0.7047 | g_loss: 3.1466
# Epoch [    7/   12] | d_loss: 0.5877 | g_loss: 1.8097
# Epoch [    7/   12] | d_loss: 0.8070 | g_loss: 2.8929
# Epoch [    7/   12] | d_loss: 0.5169 | g_loss: 2.5541
# Epoch [    7/   12] | d_loss: 0.5029 | g_loss: 0.7825
# Epoch [    7/   12] | d_loss: 0.7437 | g_loss: 1.9284
# Epoch [    7/   12] | d_loss: 0.5201 | g_loss: 3.1542
# Epoch [    7/   12] | d_loss: 1.0534 | g_loss: 3.0906
# Epoch [    7/   12] | d_loss: 0.8354 | g_loss: 1.2089
# Epoch [    8/   12] | d_loss: 0.5361 | g_loss: 2.4767
# Epoch [    8/   12] | d_loss: 0.4031 | g_loss: 3.2014
# Epoch [    8/   12] | d_loss: 0.4227 | g_loss: 2.5079
# Epoch [    8/   12] | d_loss: 0.6469 | g_loss: 2.9535
# Epoch [    8/   12] | d_loss: 0.5819 | g_loss: 1.3895
# Epoch [    8/   12] | d_loss: 0.9183 | g_loss: 4.7628
# Epoch [    8/   12] | d_loss: 0.5846 | g_loss: 3.2070
# Epoch [    8/   12] | d_loss: 0.4847 | g_loss: 2.1108
# Epoch [    8/   12] | d_loss: 0.9714 | g_loss: 1.9317
# Epoch [    8/   12] | d_loss: 0.9432 | g_loss: 3.1336
# Epoch [    8/   12] | d_loss: 0.5517 | g_loss: 3.3296
# Epoch [    8/   12] | d_loss: 0.4006 | g_loss: 2.3853
# Epoch [    8/   12] | d_loss: 0.4069 | g_loss: 2.7281
# Epoch [    8/   12] | d_loss: 0.8272 | g_loss: 2.7523
# Epoch [    8/   12] | d_loss: 0.6842 | g_loss: 1.7455
# Epoch [    9/   12] | d_loss: 0.5958 | g_loss: 1.6871
# Epoch [    9/   12] | d_loss: 0.5915 | g_loss: 3.5756
# Epoch [    9/   12] | d_loss: 0.4250 | g_loss: 4.7138
# Epoch [    9/   12] | d_loss: 0.6130 | g_loss: 2.8302
# Epoch [    9/   12] | d_loss: 0.7222 | g_loss: 2.2827
# Epoch [    9/   12] | d_loss: 0.7668 | g_loss: 2.1370
# Epoch [    9/   12] | d_loss: 0.3058 | g_loss: 4.0738
# Epoch [    9/   12] | d_loss: 0.5357 | g_loss: 2.5344
# Epoch [    9/   12] | d_loss: 0.7110 | g_loss: 2.3809
# Epoch [    9/   12] | d_loss: 0.4461 | g_loss: 2.8692
# Epoch [    9/   12] | d_loss: 0.3635 | g_loss: 1.6778
# Epoch [    9/   12] | d_loss: 0.6159 | g_loss: 1.8662
# Epoch [    9/   12] | d_loss: 0.6309 | g_loss: 2.3272
# Epoch [    9/   12] | d_loss: 1.1061 | g_loss: 2.4947
# Epoch [    9/   12] | d_loss: 0.5647 | g_loss: 1.3625
# Epoch [   10/   12] | d_loss: 0.3001 | g_loss: 3.2904
# Epoch [   10/   12] | d_loss: 0.5341 | g_loss: 2.3771
# Epoch [   10/   12] | d_loss: 0.4302 | g_loss: 1.8563
# Epoch [   10/   12] | d_loss: 0.3139 | g_loss: 1.8565
# Epoch [   10/   12] | d_loss: 1.0054 | g_loss: 1.6801
# Epoch [   10/   12] | d_loss: 0.6419 | g_loss: 0.9352
# Epoch [   10/   12] | d_loss: 0.8186 | g_loss: 3.5404
# Epoch [   10/   12] | d_loss: 0.5310 | g_loss: 2.0392
# Epoch [   10/   12] | d_loss: 0.5717 | g_loss: 1.4547
# Epoch [   10/   12] | d_loss: 0.7840 | g_loss: 1.2376
# Epoch [   10/   12] | d_loss: 1.4275 | g_loss: 2.4403
# Epoch [   10/   12] | d_loss: 0.2825 | g_loss: 1.9985
# Epoch [   10/   12] | d_loss: 0.7884 | g_loss: 1.4135
# Epoch [   10/   12] | d_loss: 0.8433 | g_loss: 0.6929
# Epoch [   10/   12] | d_loss: 0.5273 | g_loss: 2.2455
# Epoch [   11/   12] | d_loss: 0.5592 | g_loss: 2.2351
# Epoch [   11/   12] | d_loss: 0.5479 | g_loss: 2.8551
# Epoch [   11/   12] | d_loss: 0.4820 | g_loss: 1.0396
# Epoch [   11/   12] | d_loss: 0.7916 | g_loss: 1.6807
# Epoch [   11/   12] | d_loss: 0.4230 | g_loss: 3.7181
# Epoch [   11/   12] | d_loss: 0.3424 | g_loss: 1.4229
# Epoch [   11/   12] | d_loss: 0.4161 | g_loss: 1.0144
# Epoch [   11/   12] | d_loss: 0.4994 | g_loss: 2.1728
# Epoch [   11/   12] | d_loss: 0.4696 | g_loss: 2.2757
# Epoch [   11/   12] | d_loss: 0.3302 | g_loss: 2.4542
# Epoch [   11/   12] | d_loss: 0.5097 | g_loss: 1.6745
# Epoch [   11/   12] | d_loss: 0.3758 | g_loss: 3.0253
# Epoch [   11/   12] | d_loss: 0.8459 | g_loss: 2.8298
# Epoch [   11/   12] | d_loss: 0.2260 | g_loss: 2.7839
# Epoch [   11/   12] | d_loss: 0.7018 | g_loss: 1.2520
# Epoch [   12/   12] | d_loss: 0.1855 | g_loss: 2.3319
# Epoch [   12/   12] | d_loss: 0.4549 | g_loss: 3.1474
# Epoch [   12/   12] | d_loss: 0.3740 | g_loss: 1.5063
# Epoch [   12/   12] | d_loss: 0.5283 | g_loss: 1.5371
# Epoch [   12/   12] | d_loss: 0.2814 | g_loss: 1.7095
# Epoch [   12/   12] | d_loss: 0.2402 | g_loss: 3.1217
# Epoch [   12/   12] | d_loss: 0.8353 | g_loss: 0.8590
# Epoch [   12/   12] | d_loss: 0.9125 | g_loss: 4.7930
# Epoch [   12/   12] | d_loss: 0.7901 | g_loss: 3.6373
# Epoch [   12/   12] | d_loss: 0.5043 | g_loss: 1.5432
# Epoch [   12/   12] | d_loss: 0.6044 | g_loss: 3.6602
# Epoch [   12/   12] | d_loss: 0.2471 | g_loss: 3.6065
# Epoch [   12/   12] | d_loss: 0.7189 | g_loss: 3.1603
# Epoch [   12/   12] | d_loss: 0.4985 | g_loss: 3.1890
# Epoch [   12/   12] | d_loss: 0.8336 | g_loss: 1.9948

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# __Comment on Results__:
# The workspace disconnected while training and when I reconnected the cell was not reposnding so I stopped it and re-run it again. so the results is for the last 15 epochs of training, there were another 10 epochs before that.

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
# I think I reached a good point in training that most of the samples are realistic and I think it's good results. As the model was deep enough it was able to extract alot of features and by giving enough training time better results could be achieved. May be I could try adding dropout layers, trying another loss function just to compare. I repeated the same steps to generate larger images. The results looks promising but there are some scary faces down there, may be need more training time.

# %% [markdown]
# ### Training Same model on larger images

# %%
# Define function hyperparameters
batch_size = 128
img_size = 64

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader_64 = get_dataloader(batch_size, img_size)

# %%
class Discriminator_64(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator_64, self).__init__()
        self.conv_dim = conv_dim
        # complete init function
        self.conv1 = conv(3, conv_dim,4, batch_Norm=False)
        self.conv2 = conv(conv_dim, 2*conv_dim,4)
        self.conv3 = conv(2*conv_dim, 4*conv_dim,4)
        self.conv4 = conv(4*conv_dim, 8*conv_dim,4)
        
        self.fc = nn.Linear(4*4*8*conv_dim,1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        x = F.leaky_relu(self.conv4(x), 0.2)
        
        x = x.view(-1, 4*4*8*self.conv_dim)
        
        x = self.fc(x)
        
        return x

# %%
class Generator_64(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator_64, self).__init__()
        
        self.conv_dim = conv_dim
        
        self.fc = nn.Linear(z_size, 4*4*8*conv_dim)
        self.deconv1 = deconv(8*conv_dim, 4*conv_dim,4)
        self.deconv2 = deconv(4*conv_dim, 2*conv_dim,4)
        self.deconv3 = deconv(2*conv_dim,   conv_dim,4)
        self.deconv4 = deconv(conv_dim, 3, 4, batch_Norm=False)
        
        # complete init function
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        out = self.fc(x)
        out = out.view(-1,8*self.conv_dim,4,4)
        
        out = F.relu(self.deconv1(out))
        out = F.relu(self.deconv2(out))
        out = F.relu(self.deconv3(out))
        
        out = F.tanh(self.deconv4(out))
        return out

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network_64(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator_64(d_conv_dim)
    G = Generator_64(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 128 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D_64, G_64 = build_network_64(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator_64(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=8192, out_features=1, bias=True)
# )
#
# Generator_64(
#   (fc): Linear(in_features=128, out_features=8192, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %%
import torch.optim as optim
lr = 0.0002 
beta1 =0.5 
beta2 =0.9 
# Create optimizers for the discriminator D and generator G
d_optimizer_64 = optim.Adam(D_64.parameters(),lr,[beta1, beta2])
g_optimizer_64 = optim.Adam(G_64.parameters(),lr,[beta1, beta2])

# %%
def train_64(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader_64):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            if train_on_gpu:
                real_images = real_images.cuda()
            #Zero gradient
            d_optimizer_64.zero_grad()
            
            # 1. Train the discriminator on real and fake images
            #Calculate real loss
            d_real_out = D(real_images)
            d_real_loss= real_loss(d_real_out)
            
            #Generate Fake images
            z = np.random.uniform(-1,1,size=(batch_size,z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda() 
            fake_images_d= G(z)
            d_fake_out= D(fake_images_d)
            d_fake_loss= fake_loss(d_fake_out)
            
            d_loss = d_real_loss + d_fake_loss
            
            d_loss.backward()
            d_optimizer_64.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer_64.zero_grad()
            
            z = np.random.uniform(-1,1,size=(batch_size,z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda() 
            fake_images_g= G(z)
            d_g_out= D(fake_images_g)
            
            #Calculate flipped losses
            g_loss = real_loss(d_g_out)
            
            g_loss.backward()
            g_optimizer_64.step()
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples_64.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %%
# set number of epochs 
n_epochs = 15


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses_64 = train_64(D_64, G_64, n_epochs=n_epochs)
# Out:
# Epoch [    1/   15] | d_loss: 1.3890 | g_loss: 0.7066
# Epoch [    1/   15] | d_loss: 0.0920 | g_loss: 3.0520
# Epoch [    1/   15] | d_loss: 0.0094 | g_loss: 5.2538
# Epoch [    1/   15] | d_loss: 0.0010 | g_loss: 7.5242
# Epoch [    1/   15] | d_loss: 0.0001 | g_loss: 9.9456
# Epoch [    1/   15] | d_loss: 0.0039 | g_loss: 7.6147
# Epoch [    1/   15] | d_loss: 0.0005 | g_loss: 9.4032
# Epoch [    1/   15] | d_loss: 0.0001 | g_loss: 11.2279
# Epoch [    1/   15] | d_loss: 0.0000 | g_loss: 13.8383
# Epoch [    1/   15] | d_loss: 0.0000 | g_loss: 11.5225
# Epoch [    1/   15] | d_loss: 6.1205 | g_loss: 16.1580
# Epoch [    1/   15] | d_loss: 0.0494 | g_loss: 5.1322
# Epoch [    1/   15] | d_loss: 0.2344 | g_loss: 5.1015
# Epoch [    1/   15] | d_loss: 0.4051 | g_loss: 3.3962
# Epoch [    1/   15] | d_loss: 0.2530 | g_loss: 3.4871
# Epoch [    2/   15] | d_loss: 0.4752 | g_loss: 1.4717
# Epoch [    2/   15] | d_loss: 0.5555 | g_loss: 2.3259
# Epoch [    2/   15] | d_loss: 1.2317 | g_loss: 0.6794
# Epoch [    2/   15] | d_loss: 1.4624 | g_loss: 1.0047
# Epoch [    2/   15] | d_loss: 0.5669 | g_loss: 2.2303
# Epoch [    2/   15] | d_loss: 0.8170 | g_loss: 1.2366
# Epoch [    2/   15] | d_loss: 1.7273 | g_loss: 1.0615
# Epoch [    2/   15] | d_loss: 1.0219 | g_loss: 0.9699
# Epoch [    2/   15] | d_loss: 0.8938 | g_loss: 2.5791
# Epoch [    2/   15] | d_loss: 0.9301 | g_loss: 2.0204
# Epoch [    2/   15] | d_loss: 0.8100 | g_loss: 1.9577
# Epoch [    2/   15] | d_loss: 0.8307 | g_loss: 2.8073
# Epoch [    2/   15] | d_loss: 0.7358 | g_loss: 2.4967
# Epoch [    2/   15] | d_loss: 0.9492 | g_loss: 1.1170
# Epoch [    2/   15] | d_loss: 0.8133 | g_loss: 1.4966
# Epoch [    3/   15] | d_loss: 0.8025 | g_loss: 2.7194
# Epoch [    3/   15] | d_loss: 0.8978 | g_loss: 1.6964
# Epoch [    3/   15] | d_loss: 0.6552 | g_loss: 2.0150
# Epoch [    3/   15] | d_loss: 1.1027 | g_loss: 1.3773
# Epoch [    3/   15] | d_loss: 1.0362 | g_loss: 2.6476
# Epoch [    3/   15] | d_loss: 0.7934 | g_loss: 1.6761
# Epoch [    3/   15] | d_loss: 1.1827 | g_loss: 2.1173
# Epoch [    3/   15] | d_loss: 1.1054 | g_loss: 0.7196
# Epoch [    3/   15] | d_loss: 0.7879 | g_loss: 1.8088
# Epoch [    3/   15] | d_loss: 0.7946 | g_loss: 1.7005
# Epoch [    3/   15] | d_loss: 1.0105 | g_loss: 1.6355
# Epoch [    3/   15] | d_loss: 0.8656 | g_loss: 1.8482
# Epoch [    3/   15] | d_loss: 0.7076 | g_loss: 1.3224
# Epoch [    3/   15] | d_loss: 0.7373 | g_loss: 1.8173
# Epoch [    3/   15] | d_loss: 0.8577 | g_loss: 1.4957
# Epoch [    4/   15] | d_loss: 0.8377 | g_loss: 1.4970
# Epoch [    4/   15] | d_loss: 0.8758 | g_loss: 2.5925
# Epoch [    4/   15] | d_loss: 1.0079 | g_loss: 3.3729
# Epoch [    4/   15] | d_loss: 1.0636 | g_loss: 3.3178
# Epoch [    4/   15] | d_loss: 0.7688 | g_loss: 2.1398
# Epoch [    4/   15] | d_loss: 0.7882 | g_loss: 2.2391
# Epoch [    4/   15] | d_loss: 1.1851 | g_loss: 2.1478
# Epoch [    4/   15] | d_loss: 0.7306 | g_loss: 1.4243
# Epoch [    4/   15] | d_loss: 0.7442 | g_loss: 1.6733
# Epoch [    4/   15] | d_loss: 0.6142 | g_loss: 1.5045
# Epoch [    4/   15] | d_loss: 1.1027 | g_loss: 2.5726
# Epoch [    4/   15] | d_loss: 1.0017 | g_loss: 0.5089
# Epoch [    4/   15] | d_loss: 0.9676 | g_loss: 0.7681
# Epoch [    4/   15] | d_loss: 0.8000 | g_loss: 1.8496
# Epoch [    4/   15] | d_loss: 0.9324 | g_loss: 1.1334
# Epoch [    5/   15] | d_loss: 0.7999 | g_loss: 1.9414
# Epoch [    5/   15] | d_loss: 0.8260 | g_loss: 2.7119
# Epoch [    5/   15] | d_loss: 1.2206 | g_loss: 0.7231
# Epoch [    5/   15] | d_loss: 0.8987 | g_loss: 1.0095
# Epoch [    5/   15] | d_loss: 1.3101 | g_loss: 0.5085
# Epoch [    5/   15] | d_loss: 0.7416 | g_loss: 2.2073
# Epoch [    5/   15] | d_loss: 0.8344 | g_loss: 2.7170
# Epoch [    5/   15] | d_loss: 0.9056 | g_loss: 0.7606
# Epoch [    5/   15] | d_loss: 0.8895 | g_loss: 1.8611
# Epoch [    5/   15] | d_loss: 0.8367 | g_loss: 2.6766
# Epoch [    5/   15] | d_loss: 0.8003 | g_loss: 2.7502
# Epoch [    5/   15] | d_loss: 1.2737 | g_loss: 0.7298
# Epoch [    5/   15] | d_loss: 0.9153 | g_loss: 3.0965
# Epoch [    5/   15] | d_loss: 0.7558 | g_loss: 1.5628
# Epoch [    5/   15] | d_loss: 0.7330 | g_loss: 1.6314
# Epoch [    6/   15] | d_loss: 0.8131 | g_loss: 2.4641
# Epoch [    6/   15] | d_loss: 0.8104 | g_loss: 1.6891
# Epoch [    6/   15] | d_loss: 1.1326 | g_loss: 3.1283
# Epoch [    6/   15] | d_loss: 0.6864 | g_loss: 1.7510
# Epoch [    6/   15] | d_loss: 1.2461 | g_loss: 2.9115
# Epoch [    6/   15] | d_loss: 0.8407 | g_loss: 1.9722
# Epoch [    6/   15] | d_loss: 0.7026 | g_loss: 2.0015
# Epoch [    6/   15] | d_loss: 0.7411 | g_loss: 2.3266
# Epoch [    6/   15] | d_loss: 1.0074 | g_loss: 1.0976
# Epoch [    6/   15] | d_loss: 0.7432 | g_loss: 2.8023
# Epoch [    6/   15] | d_loss: 0.6127 | g_loss: 2.1577
# Epoch [    6/   15] | d_loss: 0.5306 | g_loss: 2.0666
# Epoch [    6/   15] | d_loss: 0.6447 | g_loss: 2.4664
# Epoch [    6/   15] | d_loss: 0.6302 | g_loss: 2.0472
# Epoch [    6/   15] | d_loss: 0.7016 | g_loss: 3.0798
# Epoch [    7/   15] | d_loss: 0.7875 | g_loss: 3.5134
# Epoch [    7/   15] | d_loss: 1.0238 | g_loss: 3.9729
# Epoch [    7/   15] | d_loss: 0.5928 | g_loss: 1.9492
# Epoch [    7/   15] | d_loss: 0.7423 | g_loss: 1.9144
# Epoch [    7/   15] | d_loss: 0.5126 | g_loss: 2.6597
# Epoch [    7/   15] | d_loss: 0.5373 | g_loss: 1.8116
# Epoch [    7/   15] | d_loss: 1.0288 | g_loss: 0.6659
# Epoch [    7/   15] | d_loss: 0.5115 | g_loss: 2.6894
# Epoch [    7/   15] | d_loss: 0.4175 | g_loss: 2.1732
# Epoch [    7/   15] | d_loss: 0.6119 | g_loss: 1.5168
# Epoch [    7/   15] | d_loss: 0.5103 | g_loss: 3.0597
# Epoch [    7/   15] | d_loss: 0.6489 | g_loss: 4.0511
# Epoch [    7/   15] | d_loss: 1.3372 | g_loss: 1.7251
# Epoch [    7/   15] | d_loss: 0.5499 | g_loss: 1.3023
# Epoch [    7/   15] | d_loss: 0.3918 | g_loss: 1.8870
# Epoch [    8/   15] | d_loss: 0.5493 | g_loss: 4.2653
# Epoch [    8/   15] | d_loss: 0.4989 | g_loss: 1.6935
# Epoch [    8/   15] | d_loss: 0.9700 | g_loss: 5.0629
# Epoch [    8/   15] | d_loss: 1.7689 | g_loss: 1.0738
# Epoch [    8/   15] | d_loss: 0.2878 | g_loss: 2.8325
# Epoch [    8/   15] | d_loss: 0.4320 | g_loss: 2.3188
# Epoch [    8/   15] | d_loss: 0.3769 | g_loss: 4.3275
# Epoch [    8/   15] | d_loss: 0.2499 | g_loss: 2.9206
# Epoch [    8/   15] | d_loss: 0.7890 | g_loss: 0.7428
# Epoch [    8/   15] | d_loss: 0.3310 | g_loss: 2.7105
# Epoch [    8/   15] | d_loss: 0.2482 | g_loss: 3.4472
# Epoch [    8/   15] | d_loss: 0.2407 | g_loss: 2.2800
# Epoch [    8/   15] | d_loss: 0.3598 | g_loss: 2.8130
# Epoch [    8/   15] | d_loss: 0.3124 | g_loss: 2.8474
# Epoch [    8/   15] | d_loss: 1.5452 | g_loss: 5.2523
# Epoch [    9/   15] | d_loss: 0.5952 | g_loss: 3.4280
# Epoch [    9/   15] | d_loss: 0.8011 | g_loss: 4.6052
# Epoch [    9/   15] | d_loss: 0.2401 | g_loss: 3.9124
# Epoch [    9/   15] | d_loss: 0.2839 | g_loss: 3.2597
# Epoch [    9/   15] | d_loss: 0.3369 | g_loss: 2.7792
# Epoch [    9/   15] | d_loss: 0.4880 | g_loss: 2.6775
# Epoch [    9/   15] | d_loss: 0.4575 | g_loss: 2.5098
# Epoch [    9/   15] | d_loss: 1.7023 | g_loss: 2.6098
# Epoch [    9/   15] | d_loss: 0.2268 | g_loss: 4.0350
# Epoch [    9/   15] | d_loss: 0.1684 | g_loss: 2.6912
# Epoch [    9/   15] | d_loss: 0.7860 | g_loss: 1.3981
# Epoch [    9/   15] | d_loss: 0.2502 | g_loss: 2.5343
# Epoch [    9/   15] | d_loss: 0.2944 | g_loss: 2.2652
# Epoch [    9/   15] | d_loss: 0.4050 | g_loss: 1.7874
# Epoch [    9/   15] | d_loss: 0.4345 | g_loss: 4.3556
# Epoch [   10/   15] | d_loss: 0.2235 | g_loss: 4.4347
# Epoch [   10/   15] | d_loss: 0.2603 | g_loss: 2.6718
# Epoch [   10/   15] | d_loss: 0.2983 | g_loss: 3.4972
# Epoch [   10/   15] | d_loss: 0.1938 | g_loss: 3.1214
# Epoch [   10/   15] | d_loss: 0.2960 | g_loss: 2.1638
# Epoch [   10/   15] | d_loss: 0.2595 | g_loss: 6.1524
# Epoch [   10/   15] | d_loss: 1.1191 | g_loss: 1.7580
# Epoch [   10/   15] | d_loss: 0.9308 | g_loss: 6.1636
# Epoch [   10/   15] | d_loss: 0.1310 | g_loss: 2.9082
# Epoch [   10/   15] | d_loss: 0.1145 | g_loss: 3.6830
# Epoch [   10/   15] | d_loss: 0.3987 | g_loss: 2.1937
# Epoch [   10/   15] | d_loss: 0.2072 | g_loss: 2.8014
# Epoch [   10/   15] | d_loss: 0.1742 | g_loss: 4.6698
# Epoch [   10/   15] | d_loss: 0.2857 | g_loss: 2.5001
# Epoch [   10/   15] | d_loss: 0.5465 | g_loss: 3.1596
# Epoch [   11/   15] | d_loss: 0.2979 | g_loss: 2.7623
# Epoch [   11/   15] | d_loss: 0.2400 | g_loss: 4.7682
# Epoch [   11/   15] | d_loss: 0.5615 | g_loss: 6.0503
# Epoch [   11/   15] | d_loss: 0.2083 | g_loss: 4.1663
# Epoch [   11/   15] | d_loss: 0.3736 | g_loss: 4.0015
# Epoch [   11/   15] | d_loss: 0.2198 | g_loss: 1.7957
# Epoch [   11/   15] | d_loss: 0.1832 | g_loss: 3.4706
# Epoch [   11/   15] | d_loss: 0.2836 | g_loss: 3.8757
# Epoch [   11/   15] | d_loss: 0.7185 | g_loss: 1.0331
# Epoch [   11/   15] | d_loss: 0.1536 | g_loss: 4.0948
# Epoch [   11/   15] | d_loss: 0.3370 | g_loss: 4.4284
# Epoch [   11/   15] | d_loss: 0.6310 | g_loss: 6.9735
# Epoch [   11/   15] | d_loss: 0.3215 | g_loss: 1.0397
# Epoch [   11/   15] | d_loss: 0.5503 | g_loss: 1.4740
# Epoch [   11/   15] | d_loss: 0.6685 | g_loss: 6.0816
# Epoch [   12/   15] | d_loss: 0.3247 | g_loss: 5.6783
# Epoch [   12/   15] | d_loss: 0.4851 | g_loss: 2.1201
# Epoch [   12/   15] | d_loss: 1.2296 | g_loss: 8.0894
# Epoch [   12/   15] | d_loss: 0.2868 | g_loss: 4.5149
# Epoch [   12/   15] | d_loss: 0.1755 | g_loss: 1.7998
# Epoch [   12/   15] | d_loss: 0.1132 | g_loss: 4.6001
# Epoch [   12/   15] | d_loss: 2.6326 | g_loss: 5.0188
# Epoch [   12/   15] | d_loss: 0.1077 | g_loss: 3.9242
# Epoch [   12/   15] | d_loss: 0.1317 | g_loss: 4.8945
# Epoch [   12/   15] | d_loss: 0.1838 | g_loss: 3.6211
# Epoch [   12/   15] | d_loss: 0.1701 | g_loss: 2.4796
# Epoch [   12/   15] | d_loss: 0.1626 | g_loss: 3.8498
# Epoch [   12/   15] | d_loss: 0.7621 | g_loss: 4.8824
# Epoch [   12/   15] | d_loss: 0.3273 | g_loss: 1.6038
# Epoch [   12/   15] | d_loss: 0.2592 | g_loss: 4.5395
# Epoch [   13/   15] | d_loss: 0.1572 | g_loss: 4.1228
# Epoch [   13/   15] | d_loss: 0.1038 | g_loss: 3.7528
# Epoch [   13/   15] | d_loss: 0.1495 | g_loss: 3.6932
# Epoch [   13/   15] | d_loss: 0.1099 | g_loss: 3.6502
# Epoch [   13/   15] | d_loss: 0.4537 | g_loss: 2.1420
# Epoch [   13/   15] | d_loss: 0.4691 | g_loss: 8.8437
# Epoch [   13/   15] | d_loss: 0.4131 | g_loss: 5.0423
# Epoch [   13/   15] | d_loss: 0.2048 | g_loss: 6.0775
# Epoch [   13/   15] | d_loss: 0.3480 | g_loss: 2.0065
# Epoch [   13/   15] | d_loss: 0.1594 | g_loss: 3.4183
# Epoch [   13/   15] | d_loss: 0.1607 | g_loss: 2.4644
# Epoch [   13/   15] | d_loss: 0.5111 | g_loss: 6.2959
# Epoch [   13/   15] | d_loss: 0.2006 | g_loss: 3.2151
# Epoch [   13/   15] | d_loss: 0.6553 | g_loss: 3.1234
# Epoch [   13/   15] | d_loss: 0.1403 | g_loss: 2.9296
# Epoch [   14/   15] | d_loss: 0.0647 | g_loss: 2.8055
# Epoch [   14/   15] | d_loss: 1.4026 | g_loss: 1.8000
# Epoch [   14/   15] | d_loss: 0.2282 | g_loss: 2.1603
# Epoch [   14/   15] | d_loss: 0.2469 | g_loss: 2.3254
# Epoch [   14/   15] | d_loss: 1.0523 | g_loss: 6.9677
# Epoch [   14/   15] | d_loss: 0.1537 | g_loss: 3.5822
# Epoch [   14/   15] | d_loss: 0.3631 | g_loss: 7.7375
# Epoch [   14/   15] | d_loss: 0.1778 | g_loss: 2.1190
# Epoch [   14/   15] | d_loss: 0.0900 | g_loss: 3.6432
# Epoch [   14/   15] | d_loss: 0.2553 | g_loss: 3.1244
# Epoch [   14/   15] | d_loss: 0.3689 | g_loss: 4.1394
# Epoch [   14/   15] | d_loss: 0.0733 | g_loss: 3.4944
# Epoch [   14/   15] | d_loss: 0.0634 | g_loss: 5.2841
# Epoch [   14/   15] | d_loss: 0.0505 | g_loss: 4.7421
# Epoch [   14/   15] | d_loss: 0.0786 | g_loss: 4.2647
# Epoch [   15/   15] | d_loss: 0.1155 | g_loss: 4.5536
# Epoch [   15/   15] | d_loss: 0.3181 | g_loss: 4.8296
# Epoch [   15/   15] | d_loss: 0.5470 | g_loss: 3.7619
# Epoch [   15/   15] | d_loss: 0.3212 | g_loss: 3.2459
# Epoch [   15/   15] | d_loss: 0.1445 | g_loss: 4.2145
# Epoch [   15/   15] | d_loss: 0.0749 | g_loss: 4.4984
# Epoch [   15/   15] | d_loss: 0.2349 | g_loss: 4.4375
# Epoch [   15/   15] | d_loss: 0.0858 | g_loss: 4.5585
# Epoch [   15/   15] | d_loss: 0.0723 | g_loss: 5.2803
# Epoch [   15/   15] | d_loss: 0.6264 | g_loss: 2.1841
# Epoch [   15/   15] | d_loss: 0.1747 | g_loss: 4.1420
# Epoch [   15/   15] | d_loss: 0.0779 | g_loss: 3.7292
# Epoch [   15/   15] | d_loss: 0.0865 | g_loss: 8.0416
# Epoch [   15/   15] | d_loss: 0.1184 | g_loss: 5.4240
# Epoch [   15/   15] | d_loss: 0.2780 | g_loss: 4.0957

# %%
fig, ax = plt.subplots()
losses_64 = np.array(losses_64)
plt.plot(losses_64.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses_64.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %%
# helper function for viewing a list of passed in sample images
def view_samples_64(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((64,64,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples_64.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples_64(-1, samples)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
